# %% [markdown]
# ## Representação do problema

# %%
import pandas as pd
import os

# Passo 1: Verificar os arquivos disponíveis no Colab
os.listdir('/content/')  # Isso vai listar todos os arquivos na pasta '/content/'

# Passo 2: Defina o nome do arquivo que você quer ler (substitua pelo nome do seu arquivo)
file_name = 'autopecas_motor_planilha.xlsx'  # Substitua pelo nome correto do arquivo que está no Colab

# Passo 3: Ler o arquivo XLSX
file_path = f'/content/{file_name}'

# Verificando se o arquivo realmente existe
if os.path.exists(file_path):
    # Ler o arquivo XLSX
    df = pd.read_excel(file_path)

    # Passo 4: Exibir as linhas do DataFrame
    for index, row in df.iterrows():
        print(f"Peça {index + 1}:")
        print(f"  Código: {row['Código']}")
        print(f"  Descrição: {row['Descrição']}")
        print(f"  Marca: {row['Marca']}")
        print(f"  Lote: {row['Lote']}")
        print(f"  Garantia: {row['Garantia']}")
        print("-" * 40)
else:
    print(f"Arquivo '{file_name}' não encontrado no diretório '/content/'.")
# Out:
# Peça 1:
#   Código: M0001
#   Descrição: Virabrequim
#   Marca: MarcaC
#   Lote: L196
#   Garantia: 20 meses
# ----------------------------------------
# Peça 2:
#   Código: M0002
#   Descrição: Tucho
#   Marca: MarcaD
#   Lote: L205
#   Garantia: 23 meses
# ----------------------------------------
# Peça 3:
#   Código: M0003
#   Descrição: Sensor de Pressão
#   Marca: MarcaD
#   Lote: L126
#   Garantia: 25 meses
# ----------------------------------------
# Peça 4:
#   Código: M0004
#   Descrição: Comando de Válvulas
#   Marca: MarcaB
#   Lote: L168
#   Garantia: 34 meses
# ----------------------------------------
# Peça 5:
#   Código: M0005
#   Descrição: Corrente de Comando
#   Marca: MarcaA
#   Lote: L108
#   Garantia: 22 meses
# ----------------------------------------
# Peça 6:
#   Código: M0006
#   Descrição: Comando de Válvulas
#   Marca: MarcaC
#   Lote: L127
#   Garantia: 29 meses
# ----------------------------------------
# Peça 7:
#   Código: M0007
#   Descrição: Válvula de Admissão
#   Marca: MarcaD
#   Lote: L135
#   Garantia: 22 meses
# ----------------------------------------
# Peça 8:
#   Código: M0008
#   Descrição: Bomba de Combustível
#   Marca: MarcaD
#   Lote: L195
#   Garantia: 21 meses
# ----------------------------------------
# Peça 9:
#   Código: M0009
#   Descrição: Biela
#   Marca: MarcaE
#   Lote: L167
#   Garantia: 29 meses
# ----------------------------------------
# Peça 10:
#   Código: M0010
#   Descrição: Bomba de Combustível
#   Marca: MarcaB
#   Lote: L120
#   Garantia: 28 meses
# ----------------------------------------
# Peça 11:
#   Código: M0011
#   Descrição: Pistão
#   Marca: MarcaD
#   Lote: L276
#   Garantia: 26 meses
# ----------------------------------------
# Peça 12:
#   Código: M0012
#   Descrição: Corrente de Comando
#   Marca: MarcaA
#   Lote: L197
#   Garantia: 13 meses
# ----------------------------------------
# Peça 13:
#   Código: M0013
#   Descrição: Pistão
#   Marca: MarcaB
#   Lote: L153
#   Garantia: 18 meses
# ----------------------------------------
# Peça 14:
#   Código: M0014
#   Descrição: Sensor de Temperatura
#   Marca: MarcaC
#   Lote: L254
#   Garantia: 20 meses
# ----------------------------------------
# Peça 15:
#   Código: M0015
#   Descrição: Virabrequim
#   Marca: MarcaD
#   Lote: L115
#   Garantia: 25 meses
# ----------------------------------------
# Peça 16:
#   Código: M0016
#   Descrição: Retentor
#   Marca: MarcaB
#   Lote: L248
#   Garantia: 12 meses
# ----------------------------------------
# Peça 17:
#   Código: M0017
#   Descrição: Comando de Válvulas
#   Marca: MarcaB
#   Lote: L283
#   Garantia: 15 meses
# ----------------------------------------
# Peça 18:
#   Código: M0018
#   Descrição: Corrente de Comando
#   Marca: MarcaB
#   Lote: L296
#   Garantia: 30 meses
# ----------------------------------------
# Peça 19:
#   Código: M0019
#   Descrição: Comando de Válvulas
#   Marca: MarcaB
#   Lote: L197
#   Garantia: 17 meses
# ----------------------------------------
# Peça 20:
#   Código: M0020
#   Descrição: Tucho
#   Marca: MarcaE
#   Lote: L200
#   Garantia: 21 meses
# ----------------------------------------
# Peça 21:
#   Código: M0021
#   Descrição: Sensor de Temperatura
#   Marca: MarcaE
#   Lote: L101
#   Garantia: 21 meses
# ----------------------------------------
# Peça 22:
#   Código: M0022
#   Descrição: Injetor de Combustível
#   Marca: MarcaE
#   Lote: L123
#   Garantia: 28 meses
# ----------------------------------------
# Peça 23:
#   Código: M0023
#   Descrição: Anel de Pistão
#   Marca: MarcaC
#   Lote: L222
#   Garantia: 24 meses
# ----------------------------------------
# Peça 24:
#   Código: M0024
#   Descrição: Biela
#   Marca: MarcaA
#   Lote: L143
#   Garantia: 21 meses
# ----------------------------------------
# Peça 25:
#   Código: M0025
#   Descrição: Biela
#   Marca: MarcaD
#   Lote: L115
#   Garantia: 32 meses
# ----------------------------------------
# Peça 26:
#   Código: M0026
#   Descrição: Filtro de Óleo
#   Marca: MarcaC
#   Lote: L246
#   Garantia: 23 meses
# ----------------------------------------
# Peça 27:
#   Código: M0027
#   Descrição: Comando de Válvulas
#   Marca: MarcaD
#   Lote: L145
#   Garantia: 12 meses
# ----------------------------------------
# Peça 28:
#   Código: M0028
#   Descrição: Anel de Pistão
#   Marca: MarcaB
#   Lote: L209
#   Garantia: 22 meses
# ----------------------------------------
# Peça 29:
#   Código: M0029
#   Descrição: Anel de Pistão
#   Marca: MarcaB
#   Lote: L166
#   Garantia: 36 meses
# ----------------------------------------
# Peça 30:
#   Código: M0030
#   Descrição: Bomba de Combustível
#   Marca: MarcaB
#   Lote: L217
#   Garantia: 19 meses
# ----------------------------------------
# Peça 31:
#   Código: M0031
#   Descrição: Cabeçote
#   Marca: MarcaD
#   Lote: L163
#   Garantia: 23 meses
# ----------------------------------------
# Peça 32:
#   Código: M0032
#   Descrição: Válvula de Admissão
#   Marca: MarcaA
#   Lote: L196
#   Garantia: 26 meses
# ----------------------------------------
# Peça 33:
#   Código: M0033
#   Descrição: Sensor de Temperatura
#   Marca: MarcaA
#   Lote: L112
#   Garantia: 15 meses
# ----------------------------------------
# Peça 34:
#   Código: M0034
#   Descrição: Sensor de Pressão
#   Marca: MarcaC
#   Lote: L281
#   Garantia: 17 meses
# ----------------------------------------
# Peça 35:
#   Código: M0035
#   Descrição: Junta do Cabeçote
#   Marca: MarcaD
#   Lote: L105
#   Garantia: 27 meses
# ----------------------------------------
# Peça 36:
#   Código: M0036
#   Descrição: Bomba de Óleo
#   Marca: MarcaC
#   Lote: L209
#   Garantia: 24 meses
# ----------------------------------------
# Peça 37:
#   Código: M0037
#   Descrição: Bomba de Combustível
#   Marca: MarcaA
#   Lote: L106
#   Garantia: 12 meses
# ----------------------------------------
# Peça 38:
#   Código: M0038
#   Descrição: Pistão
#   Marca: MarcaE
#   Lote: L224
#   Garantia: 16 meses
# ----------------------------------------
# Peça 39:
#   Código: M0039
#   Descrição: Vela de Ignição
#   Marca: MarcaD
#   Lote: L216
#   Garantia: 15 meses
# ----------------------------------------
# Peça 40:
#   Código: M0040
#   Descrição: Válvula de Admissão
#   Marca: MarcaE
#   Lote: L227
#   Garantia: 23 meses
# ----------------------------------------
# Peça 41:
#   Código: M0041
#   Descrição: Junta do Cabeçote
#   Marca: MarcaC
#   Lote: L171
#   Garantia: 27 meses
# ----------------------------------------
# Peça 42:
#   Código: M0042
#   Descrição: Cárter
#   Marca: MarcaC
#   Lote: L283
#   Garantia: 28 meses
# ----------------------------------------
# Peça 43:
#   Código: M0043
#   Descrição: Injetor de Combustível
#   Marca: MarcaA
#   Lote: L131
#   Garantia: 24 meses
# ----------------------------------------
# Peça 44:
#   Código: M0044
#   Descrição: Sensor de Pressão
#   Marca: MarcaC
#   Lote: L164
#   Garantia: 28 meses
# ----------------------------------------
# Peça 45:
#   Código: M0045
#   Descrição: Bomba de Combustível
#   Marca: MarcaA
#   Lote: L161
#   Garantia: 16 meses
# ----------------------------------------
# Peça 46:
#   Código: M0046
#   Descrição: Tucho
#   Marca: MarcaE
#   Lote: L129
#   Garantia: 18 meses
# ----------------------------------------
# Peça 47:
#   Código: M0047
#   Descrição: Corrente de Comando
#   Marca: MarcaA
#   Lote: L227
#   Garantia: 35 meses
# ----------------------------------------
# Peça 48:
#   Código: M0048
#   Descrição: Junta do Cabeçote
#   Marca: MarcaB
#   Lote: L253
#   Garantia: 35 meses
# ----------------------------------------
# Peça 49:
#   Código: M0049
#   Descrição: Comando de Válvulas
#   Marca: MarcaB
#   Lote: L283
#   Garantia: 18 meses
# ----------------------------------------
# Peça 50:
#   Código: M0050
#   Descrição: Pistão
#   Marca: MarcaB
#   Lote: L176
#   Garantia: 18 meses
# ----------------------------------------
# Peça 51:
#   Código: M0051
#   Descrição: Biela
#   Marca: MarcaA
#   Lote: L199
#   Garantia: 23 meses
# ----------------------------------------
# Peça 52:
#   Código: M0052
#   Descrição: Cárter
#   Marca: MarcaD
#   Lote: L279
#   Garantia: 36 meses
# ----------------------------------------
# Peça 53:
#   Código: M0053
#   Descrição: Cárter
#   Marca: MarcaE
#   Lote: L198
#   Garantia: 23 meses
# ----------------------------------------
# Peça 54:
#   Código: M0054
#   Descrição: Anel de Pistão
#   Marca: MarcaB
#   Lote: L163
#   Garantia: 31 meses
# ----------------------------------------
# Peça 55:
#   Código: M0055
#   Descrição: Tucho
#   Marca: MarcaA
#   Lote: L129
#   Garantia: 24 meses
# ----------------------------------------
# Peça 56:
#   Código: M0056
#   Descrição: Retentor
#   Marca: MarcaC
#   Lote: L151
#   Garantia: 18 meses
# ----------------------------------------
# Peça 57:
#   Código: M0057
#   Descrição: Filtro de Óleo
#   Marca: MarcaE
#   Lote: L300
#   Garantia: 13 meses
# ----------------------------------------
# Peça 58:
#   Código: M0058
#   Descrição: Válvula de Admissão
#   Marca: MarcaE
#   Lote: L180
#   Garantia: 26 meses
# ----------------------------------------
# Peça 59:
#   Código: M0059
#   Descrição: Cabeçote
#   Marca: MarcaC
#   Lote: L124
#   Garantia: 14 meses
# ----------------------------------------
# Peça 60:
#   Código: M0060
#   Descrição: Virabrequim
#   Marca: MarcaE
#   Lote: L276
#   Garantia: 35 meses
# ----------------------------------------
# Peça 61:
#   Código: M0061
#   Descrição: Vela de Ignição
#   Marca: MarcaE
#   Lote: L132
#   Garantia: 25 meses
# ----------------------------------------
# Peça 62:
#   Código: M0062
#   Descrição: Sensor de Pressão
#   Marca: MarcaD
#   Lote: L139
#   Garantia: 31 meses
# ----------------------------------------
# Peça 63:
#   Código: M0063
#   Descrição: Tucho
#   Marca: MarcaC
#   Lote: L185
#   Garantia: 25 meses
# ----------------------------------------
# Peça 64:
#   Código: M0064
#   Descrição: Virabrequim
#   Marca: MarcaD
#   Lote: L287
#   Garantia: 24 meses
# ----------------------------------------
# Peça 65:
#   Código: M0065
#   Descrição: Injetor de Combustível
#   Marca: MarcaC
#   Lote: L258
#   Garantia: 13 meses
# ----------------------------------------
# Peça 66:
#   Código: M0066
#   Descrição: Tucho
#   Marca: MarcaB
#   Lote: L232
#   Garantia: 22 meses
# ----------------------------------------
# Peça 67:
#   Código: M0067
#   Descrição: Sensor de Temperatura
#   Marca: MarcaC
#   Lote: L211
#   Garantia: 27 meses
# ----------------------------------------
# Peça 68:
#   Código: M0068
#   Descrição: Sensor de Pressão
#   Marca: MarcaE
#   Lote: L214
#   Garantia: 24 meses
# ----------------------------------------
# Peça 69:
#   Código: M0069
#   Descrição: Válvula de Admissão
#   Marca: MarcaD
#   Lote: L274
#   Garantia: 13 meses
# ----------------------------------------
# Peça 70:
#   Código: M0070
#   Descrição: Junta do Cabeçote
#   Marca: MarcaD
#   Lote: L268
#   Garantia: 12 meses
# ----------------------------------------
# Peça 71:
#   Código: M0071
#   Descrição: Filtro de Óleo
#   Marca: MarcaB
#   Lote: L161
#   Garantia: 18 meses
# ----------------------------------------
# Peça 72:
#   Código: M0072
#   Descrição: Sensor de Temperatura
#   Marca: MarcaB
#   Lote: L180
#   Garantia: 27 meses
# ----------------------------------------
# Peça 73:
#   Código: M0073
#   Descrição: Vela de Ignição
#   Marca: MarcaA
#   Lote: L257
#   Garantia: 25 meses
# ----------------------------------------
# Peça 74:
#   Código: M0074
#   Descrição: Bomba de Óleo
#   Marca: MarcaE
#   Lote: L264
#   Garantia: 23 meses
# ----------------------------------------
# Peça 75:
#   Código: M0075
#   Descrição: Corrente de Comando
#   Marca: MarcaB
#   Lote: L190
#   Garantia: 14 meses
# ----------------------------------------
# Peça 76:
#   Código: M0076
#   Descrição: Injetor de Combustível
#   Marca: MarcaB
#   Lote: L164
#   Garantia: 20 meses
# ----------------------------------------
# Peça 77:
#   Código: M0077
#   Descrição: Comando de Válvulas
#   Marca: MarcaA
#   Lote: L275
#   Garantia: 31 meses
# ----------------------------------------
# Peça 78:
#   Código: M0078
#   Descrição: Corrente de Comando
#   Marca: MarcaA
#   Lote: L127
#   Garantia: 21 meses
# ----------------------------------------
# Peça 79:
#   Código: M0079
#   Descrição: Válvula de Admissão
#   Marca: MarcaE
#   Lote: L121
#   Garantia: 15 meses
# ----------------------------------------
# Peça 80:
#   Código: M0080
#   Descrição: Pistão
#   Marca: MarcaC
#   Lote: L273
#   Garantia: 33 meses
# ----------------------------------------
# Peça 81:
#   Código: M0081
#   Descrição: Injetor de Combustível
#   Marca: MarcaC
#   Lote: L241
#   Garantia: 22 meses
# ----------------------------------------
# Peça 82:
#   Código: M0082
#   Descrição: Válvula de Escape
#   Marca: MarcaC
#   Lote: L170
#   Garantia: 20 meses
# ----------------------------------------
# Peça 83:
#   Código: M0083
#   Descrição: Bomba de Óleo
#   Marca: MarcaD
#   Lote: L280
#   Garantia: 19 meses
# ----------------------------------------
# Peça 84:
#   Código: M0084
#   Descrição: Tucho
#   Marca: MarcaD
#   Lote: L108
#   Garantia: 36 meses
# ----------------------------------------
# Peça 85:
#   Código: M0085
#   Descrição: Junta do Cabeçote
#   Marca: MarcaB
#   Lote: L278
#   Garantia: 16 meses
# ----------------------------------------
# Peça 86:
#   Código: M0086
#   Descrição: Vela de Ignição
#   Marca: MarcaA
#   Lote: L132
#   Garantia: 15 meses
# ----------------------------------------
# Peça 87:
#   Código: M0087
#   Descrição: Válvula de Admissão
#   Marca: MarcaB
#   Lote: L289
#   Garantia: 28 meses
# ----------------------------------------
# Peça 88:
#   Código: M0088
#   Descrição: Pistão
#   Marca: MarcaD
#   Lote: L290
#   Garantia: 31 meses
# ----------------------------------------
# Peça 89:
#   Código: M0089
#   Descrição: Retentor
#   Marca: MarcaA
#   Lote: L236
#   Garantia: 16 meses
# ----------------------------------------
# Peça 90:
#   Código: M0090
#   Descrição: Virabrequim
#   Marca: MarcaA
#   Lote: L255
#   Garantia: 14 meses
# ----------------------------------------
# Peça 91:
#   Código: M0091
#   Descrição: Virabrequim
#   Marca: MarcaA
#   Lote: L108
#   Garantia: 25 meses
# ----------------------------------------
# Peça 92:
#   Código: M0092
#   Descrição: Válvula de Admissão
#   Marca: MarcaE
#   Lote: L282
#   Garantia: 31 meses
# ----------------------------------------
# Peça 93:
#   Código: M0093
#   Descrição: Pistão
#   Marca: MarcaC
#   Lote: L106
#   Garantia: 29 meses
# ----------------------------------------
# Peça 94:
#   Código: M0094
#   Descrição: Cárter
#   Marca: MarcaE
#   Lote: L120
#   Garantia: 18 meses
# ----------------------------------------
# Peça 95:
#   Código: M0095
#   Descrição: Cárter
#   Marca: MarcaA
#   Lote: L186
#   Garantia: 24 meses
# ----------------------------------------
# Peça 96:
#   Código: M0096
#   Descrição: Pistão
#   Marca: MarcaD
#   Lote: L240
#   Garantia: 13 meses
# ----------------------------------------
# Peça 97:
#   Código: M0097
#   Descrição: Pistão
#   Marca: MarcaD
#   Lote: L108
#   Garantia: 36 meses
# ----------------------------------------
# Peça 98:
#   Código: M0098
#   Descrição: Corrente de Comando
#   Marca: MarcaC
#   Lote: L287
#   Garantia: 32 meses
# ----------------------------------------
# Peça 99:
#   Código: M0099
#   Descrição: Sensor de Pressão
#   Marca: MarcaD
#   Lote: L270
#   Garantia: 31 meses
# ----------------------------------------
# Peça 100:
#   Código: M0100
#   Descrição: Bomba de Combustível
#   Marca: MarcaB
#   Lote: L172
#   Garantia: 34 meses
# ----------------------------------------
# Peça 101:
#   Código: M0101
#   Descrição: Anel de Pistão
#   Marca: MarcaE
#   Lote: L169
#   Garantia: 30 meses
# ----------------------------------------
# Peça 102:
#   Código: M0102
#   Descrição: Válvula de Admissão
#   Marca: MarcaB
#   Lote: L133
#   Garantia: 25 meses
# ----------------------------------------
# Peça 103:
#   Código: M0103
#   Descrição: Pistão
#   Marca: MarcaA
#   Lote: L247
#   Garantia: 30 meses
# ----------------------------------------
# Peça 104:
#   Código: M0104
#   Descrição: Corrente de Comando
#   Marca: MarcaB
#   Lote: L256
#   Garantia: 36 meses
# ----------------------------------------
# Peça 105:
#   Código: M0105
#   Descrição: Filtro de Óleo
#   Marca: MarcaE
#   Lote: L255
#   Garantia: 33 meses
# ----------------------------------------
# Peça 106:
#   Código: M0106
#   Descrição: Cabeçote
#   Marca: MarcaC
#   Lote: L131
#   Garantia: 34 meses
# ----------------------------------------
# Peça 107:
#   Código: M0107
#   Descrição: Sensor de Temperatura
#   Marca: MarcaD
#   Lote: L175
#   Garantia: 19 meses
# ----------------------------------------
# Peça 108:
#   Código: M0108
#   Descrição: Anel de Pistão
#   Marca: MarcaC
#   Lote: L133
#   Garantia: 29 meses
# ----------------------------------------
# Peça 109:
#   Código: M0109
#   Descrição: Tucho
#   Marca: MarcaD
#   Lote: L102
#   Garantia: 21 meses
# ----------------------------------------
# Peça 110:
#   Código: M0110
#   Descrição: Bomba de Combustível
#   Marca: MarcaD
#   Lote: L191
#   Garantia: 34 meses
# ----------------------------------------
# Peça 111:
#   Código: M0111
#   Descrição: Comando de Válvulas
#   Marca: MarcaA
#   Lote: L250
#   Garantia: 26 meses
# ----------------------------------------
# Peça 112:
#   Código: M0112
#   Descrição: Virabrequim
#   Marca: MarcaD
#   Lote: L197
#   Garantia: 25 meses
# ----------------------------------------
# Peça 113:
#   Código: M0113
#   Descrição: Comando de Válvulas
#   Marca: MarcaB
#   Lote: L296
#   Garantia: 23 meses
# ----------------------------------------
# Peça 114:
#   Código: M0114
#   Descrição: Válvula de Escape
#   Marca: MarcaA
#   Lote: L125
#   Garantia: 36 meses
# ----------------------------------------
# Peça 115:
#   Código: M0115
#   Descrição: Válvula de Admissão
#   Marca: MarcaA
#   Lote: L181
#   Garantia: 24 meses
# ----------------------------------------
# Peça 116:
#   Código: M0116
#   Descrição: Sensor de Pressão
#   Marca: MarcaD
#   Lote: L160
#   Garantia: 20 meses
# ----------------------------------------
# Peça 117:
#   Código: M0117
#   Descrição: Sensor de Pressão
#   Marca: MarcaC
#   Lote: L274
#   Garantia: 25 meses
# ----------------------------------------
# Peça 118:
#   Código: M0118
#   Descrição: Anel de Pistão
#   Marca: MarcaE
#   Lote: L177
#   Garantia: 27 meses
# ----------------------------------------
# Peça 119:
#   Código: M0119
#   Descrição: Bomba de Óleo
#   Marca: MarcaC
#   Lote: L266
#   Garantia: 30 meses
# ----------------------------------------
# Peça 120:
#   Código: M0120
#   Descrição: Retentor
#   Marca: MarcaC
#   Lote: L180
#   Garantia: 25 meses
# ----------------------------------------
# Peça 121:
#   Código: M0121
#   Descrição: Corrente de Comando
#   Marca: MarcaD
#   Lote: L218
#   Garantia: 26 meses
# ----------------------------------------
# Peça 122:
#   Código: M0122
#   Descrição: Biela
#   Marca: MarcaB
#   Lote: L271
#   Garantia: 17 meses
# ----------------------------------------
# Peça 123:
#   Código: M0123
#   Descrição: Corrente de Comando
#   Marca: MarcaE
#   Lote: L243
#   Garantia: 32 meses
# ----------------------------------------
# Peça 124:
#   Código: M0124
#   Descrição: Cabeçote
#   Marca: MarcaA
#   Lote: L261
#   Garantia: 13 meses
# ----------------------------------------
# Peça 125:
#   Código: M0125
#   Descrição: Bomba de Combustível
#   Marca: MarcaD
#   Lote: L247
#   Garantia: 24 meses
# ----------------------------------------
# Peça 126:
#   Código: M0126
#   Descrição: Bomba de Combustível
#   Marca: MarcaC
#   Lote: L227
#   Garantia: 22 meses
# ----------------------------------------
# Peça 127:
#   Código: M0127
#   Descrição: Comando de Válvulas
#   Marca: MarcaC
#   Lote: L139
#   Garantia: 35 meses
# ----------------------------------------
# Peça 128:
#   Código: M0128
#   Descrição: Tucho
#   Marca: MarcaB
#   Lote: L244
#   Garantia: 34 meses
# ----------------------------------------
# Peça 129:
#   Código: M0129
#   Descrição: Sensor de Pressão
#   Marca: MarcaA
#   Lote: L275
#   Garantia: 25 meses
# ----------------------------------------
# Peça 130:
#   Código: M0130
#   Descrição: Comando de Válvulas
#   Marca: MarcaD
#   Lote: L247
#   Garantia: 14 meses
# ----------------------------------------
# Peça 131:
#   Código: M0131
#   Descrição: Filtro de Óleo
#   Marca: MarcaC
#   Lote: L273
#   Garantia: 28 meses
# ----------------------------------------
# Peça 132:
#   Código: M0132
#   Descrição: Retentor
#   Marca: MarcaB
#   Lote: L284
#   Garantia: 28 meses
# ----------------------------------------
# Peça 133:
#   Código: M0133
#   Descrição: Cabeçote
#   Marca: MarcaA
#   Lote: L232
#   Garantia: 27 meses
# ----------------------------------------
# Peça 134:
#   Código: M0134
#   Descrição: Anel de Pistão
#   Marca: MarcaC
#   Lote: L177
#   Garantia: 15 meses
# ----------------------------------------
# Peça 135:
#   Código: M0135
#   Descrição: Cárter
#   Marca: MarcaC
#   Lote: L293
#   Garantia: 18 meses
# ----------------------------------------
# Peça 136:
#   Código: M0136
#   Descrição: Junta do Cabeçote
#   Marca: MarcaD
#   Lote: L140
#   Garantia: 27 meses
# ----------------------------------------
# Peça 137:
#   Código: M0137
#   Descrição: Tucho
#   Marca: MarcaD
#   Lote: L278
#   Garantia: 26 meses
# ----------------------------------------
# Peça 138:
#   Código: M0138
#   Descrição: Filtro de Óleo
#   Marca: MarcaD
#   Lote: L296
#   Garantia: 32 meses
# ----------------------------------------
# Peça 139:
#   Código: M0139
#   Descrição: Tucho
#   Marca: MarcaE
#   Lote: L261
#   Garantia: 24 meses
# ----------------------------------------
# Peça 140:
#   Código: M0140
#   Descrição: Vela de Ignição
#   Marca: MarcaD
#   Lote: L231
#   Garantia: 17 meses
# ----------------------------------------
# Peça 141:
#   Código: M0141
#   Descrição: Junta do Cabeçote
#   Marca: MarcaC
#   Lote: L127
#   Garantia: 36 meses
# ----------------------------------------
# Peça 142:
#   Código: M0142
#   Descrição: Retentor
#   Marca: MarcaE
#   Lote: L292
#   Garantia: 22 meses
# ----------------------------------------
# Peça 143:
#   Código: M0143
#   Descrição: Tucho
#   Marca: MarcaB
#   Lote: L258
#   Garantia: 23 meses
# ----------------------------------------
# Peça 144:
#   Código: M0144
#   Descrição: Retentor
#   Marca: MarcaC
#   Lote: L115
#   Garantia: 18 meses
# ----------------------------------------
# Peça 145:
#   Código: M0145
#   Descrição: Corrente de Comando
#   Marca: MarcaE
#   Lote: L221
#   Garantia: 33 meses
# ----------------------------------------
# Peça 146:
#   Código: M0146
#   Descrição: Filtro de Óleo
#   Marca: MarcaD
#   Lote: L171
#   Garantia: 36 meses
# ----------------------------------------
# Peça 147:
#   Código: M0147
#   Descrição: Válvula de Admissão
#   Marca: MarcaB
#   Lote: L258
#   Garantia: 27 meses
# ----------------------------------------
# Peça 148:
#   Código: M0148
#   Descrição: Bomba de Combustível
#   Marca: MarcaC
#   Lote: L111
#   Garantia: 36 meses
# ----------------------------------------
# Peça 149:
#   Código: M0149
#   Descrição: Bomba de Óleo
#   Marca: MarcaB
#   Lote: L119
#   Garantia: 25 meses
# ----------------------------------------
# Peça 150:
#   Código: M0150
#   Descrição: Filtro de Óleo
#   Marca: MarcaB
#   Lote: L279
#   Garantia: 22 meses
# ----------------------------------------

# %%
import pandas as pd
import os

def verificar_marcas_mais_acionadas_garantia(file_name):
    # Verifica se o arquivo existe
    file_path = f'/content/{file_name}'

    if not os.path.exists(file_path):
        print(f"Arquivo '{file_name}' não encontrado no diretório '/content/'.")
        return

    # Carrega o arquivo XLSX
    df = pd.read_excel(file_path)

    # Verifica se a coluna 'Garantia' existe no DataFrame
    if 'Garantia' not in df.columns:
        print("A coluna 'Garantia' não foi encontrada no arquivo.")
        return

    # Filtra as linhas onde a Garantia não está vazia
    garantia_acionada = df[df['Garantia'].notna()]
    total_pecas = len(df)

    # Contagem de ocorrências das marcas
    marcas_contagem = garantia_acionada['Marca'].value_counts()

    # Exibe as marcas mais acionadas
    if marcas_contagem.empty:
        print("Não há registros de garantia acionada.")
    else:
        print("Marcas mais acionadas para garantia:")
        for marca, quantidade in marcas_contagem.items():
            print(f"{marca}: {quantidade} retornos de garantia")

        # Exibe o total de peças
        print(f"\nTotal de peças na planilha: {total_pecas}")

# %%
# Exemplo de uso da função:
file_name = 'autopecas_motor_planilha.xlsx'  # Substitua pelo nome do arquivo no Colab
verificar_marcas_mais_acionadas_garantia(file_name)
# Out:
# Marcas mais acionadas para garantia:
# MarcaD: 35 retornos de garantia
# MarcaC: 33 retornos de garantia
# MarcaB: 32 retornos de garantia
# MarcaA: 26 retornos de garantia
# MarcaE: 24 retornos de garantia
#
# Total de peças na planilha: 150

# %% [markdown]
# ## Fitness function

# %%
import pandas as pd
import os

def fitness_function(file_name, objetivo_retorno_min=50, objetivo_retorno_max=100):
    # Verifica se o arquivo existe no diretório
    file_path = f'/content/{file_name}'

    if not os.path.exists(file_path):
        print(f"Arquivo '{file_name}' não encontrado no diretório '/content/'.")
        return None

    # Carregar o arquivo XLSX
    df = pd.read_excel(file_path)

    # Verificar se as colunas necessárias existem no DataFrame
    if 'Marca' not in df.columns or 'Retornos de Garantia (Mensal)' not in df.columns:
        print("As colunas necessárias não foram encontradas no arquivo.")
        return None

    # Converter a coluna de 'Retornos de Garantia (Mensal)' para número inteiro
    df['Retornos de Garantia (Mensal)'] = pd.to_numeric(df['Retornos de Garantia (Mensal)'], errors='coerce')

    # Criar um DataFrame vazio para armazenar os retornos por marca e mês
    retornos_por_marca_mes = []

    # Iterar sobre cada linha para organizar os retornos por marca e mês
    for index, row in df.iterrows():
        mes = pd.to_datetime('today').replace(day=1)  # Primeiro dia do mês atual
        marca = row['Marca']
        quantidade_retorno = row['Retornos de Garantia (Mensal)']

        # Adiciona para o mês atual
        retornos_por_marca_mes.append([marca, mes, quantidade_retorno])

    # Criar um DataFrame com os retornos por marca e mês
    retornos_df = pd.DataFrame(retornos_por_marca_mes, columns=['Marca', 'Mes', 'Retornos'])

    # Garantir que 'Mes' esteja no formato datetime para agrupamento adequado
    retornos_df['Mes'] = pd.to_datetime(retornos_df['Mes']).dt.to_period('M')

    # Agrupar por 'Marca' e 'Mes' e somar os retornos de garantia (quantidade de peças retornadas)
    resultados = retornos_df.groupby(['Marca', 'Mes'])['Retornos'].sum().unstack(fill_value=0)

    # Se não houver dados
    if resultados.empty:
        print("Não há registros de retorno de garantia.")
        return None

    # Relatório detalhado sobre os resultados
    relatorio = []

    # Avaliar cada valor de retorno de garantia
    for marca in resultados.index:
        for mes in resultados.columns:
            quantidade_retorno = resultados.loc[marca, mes]

            # Criar a avaliação para cada marca/mês
            if objetivo_retorno_min <= quantidade_retorno <= objetivo_retorno_max:
                status = "Dentro do intervalo ideal"
                pontuacao = f"Pontuação +1 (Retorno de garantia {quantidade_retorno} dentro do intervalo {objetivo_retorno_min} a {objetivo_retorno_max})"
            else:
                status = "Fora do intervalo ideal"
                pontuacao = f"Pontuação -1 (Retorno de garantia {quantidade_retorno} fora do intervalo {objetivo_retorno_min} a {objetivo_retorno_max})"

            # Adiciona o resultado detalhado no relatório
            relatorio.append({
                'Marca': marca,
                'Mês': str(mes),  # Convertendo para string para facilitar a visualização
                'Quantidade de Retornos': quantidade_retorno,
                'Status': status,
                'Pontuação': pontuacao
            })

    # Mostrar o relatório detalhado
    for item in relatorio:
        print(f"Marca: {item['Marca']}, Mês: {item['Mês']}, Quantidade de Retornos: {item['Quantidade de Retornos']}")
        print(f"Status: {item['Status']}")
        print(f"Detalhamento: {item['Pontuação']}")
        print("-" * 80)

    # Calcular a pontuação total
    fitness_total = sum(1 if 'Dentro do intervalo ideal' in item['Status'] else -1 for item in relatorio)

    return fitness_total

    # Exemplo de uso:
file_name = 'autopecas_motor_planilha.xlsx'  # Substitua pelo nome do seu arquivo
fitness = fitness_function(file_name, objetivo_retorno_min=50, objetivo_retorno_max=80)

if fitness is not None:
    print(f"A pontuação de fitness dos retornos de garantia é: {fitness}")
# Out:
# Marca: MarcaA, Mês: 2024-11, Quantidade de Retornos: 56
# Status: Dentro do intervalo ideal
# Detalhamento: Pontuação +1 (Retorno de garantia 56 dentro do intervalo 50 a 80)
# --------------------------------------------------------------------------------
# Marca: MarcaB, Mês: 2024-11, Quantidade de Retornos: 96
# Status: Fora do intervalo ideal
# Detalhamento: Pontuação -1 (Retorno de garantia 96 fora do intervalo 50 a 80)
# --------------------------------------------------------------------------------
# Marca: MarcaC, Mês: 2024-11, Quantidade de Retornos: 82
# Status: Fora do intervalo ideal
# Detalhamento: Pontuação -1 (Retorno de garantia 82 fora do intervalo 50 a 80)
# --------------------------------------------------------------------------------
# Marca: MarcaD, Mês: 2024-11, Quantidade de Retornos: 88
# Status: Fora do intervalo ideal
# Detalhamento: Pontuação -1 (Retorno de garantia 88 fora do intervalo 50 a 80)
# --------------------------------------------------------------------------------
# Marca: MarcaE, Mês: 2024-11, Quantidade de Retornos: 71
# Status: Dentro do intervalo ideal
# Detalhamento: Pontuação +1 (Retorno de garantia 71 dentro do intervalo 50 a 80)
# --------------------------------------------------------------------------------
# A pontuação de fitness dos retornos de garantia é: -1

# %% [markdown]
# ## Hill climb

# %%
import pandas as pd
import os
import random

def fitness_function(file_name, objetivo_retorno_min=50, objetivo_retorno_max=100):
    """
    Avalia a qualidade dos retornos de garantia por marca e mês.
    - A função compara os retornos com os valores ideais e retorna uma pontuação de fitness.

    :param file_name: Nome do arquivo Excel com os dados de retornos de garantia.
    :param objetivo_retorno_min: Valor mínimo ideal de retornos de garantia por mês.
    :param objetivo_retorno_max: Valor máximo ideal de retornos de garantia por mês.
    :return: A pontuação de fitness total para os retornos de garantia.
    """
    # Verifica se o arquivo existe no diretório
    file_path = f'/content/{file_name}'

    if not os.path.exists(file_path):
        print(f"Arquivo '{file_name}' não encontrado no diretório '/content/'.")
        return None

    # Carregar o arquivo XLSX
    df = pd.read_excel(file_path)

    # Verificar se as colunas necessárias existem no DataFrame
    if 'Marca' not in df.columns or 'Retornos de Garantia (Mensal)' not in df.columns:
        print("As colunas necessárias não foram encontradas no arquivo.")
        return None

    # Converter a coluna de 'Retornos de Garantia (Mensal)' para número inteiro
    df['Retornos de Garantia (Mensal)'] = pd.to_numeric(df['Retornos de Garantia (Mensal)'], errors='coerce')

    # Criar um DataFrame vazio para armazenar os retornos por marca e mês
    retornos_por_marca_mes = []

    # Iterar sobre cada linha para organizar os retornos por marca e mês
    for index, row in df.iterrows():
        mes = pd.to_datetime('today').replace(day=1)  # Primeiro dia do mês atual
        marca = row['Marca']
        quantidade_retorno = row['Retornos de Garantia (Mensal)']

        # Adiciona para o mês atual
        retornos_por_marca_mes.append([marca, mes, quantidade_retorno])

    # Criar um DataFrame com os retornos por marca e mês
    retornos_df = pd.DataFrame(retornos_por_marca_mes, columns=['Marca', 'Mes', 'Retornos'])

    # Garantir que 'Mes' esteja no formato datetime para agrupamento adequado
    retornos_df['Mes'] = pd.to_datetime(retornos_df['Mes']).dt.to_period('M')

    # Agrupar por 'Marca' e 'Mes' e somar os retornos de garantia (quantidade de peças retornadas)
    resultados = retornos_df.groupby(['Marca', 'Mes'])['Retornos'].sum().unstack(fill_value=0)

    # Se não houver dados
    if resultados.empty:
        print("Não há registros de retorno de garantia.")
        return None

    # Relatório detalhado sobre os resultados
    relatorio = []

    # Avaliar cada valor de retorno de garantia
    for marca in resultados.index:
        for mes in resultados.columns:
            quantidade_retorno = resultados.loc[marca, mes]

            # Criar a avaliação para cada marca/mês
            if objetivo_retorno_min <= quantidade_retorno <= objetivo_retorno_max:
                status = "Dentro do intervalo ideal"
                pontuacao = 1  # Pontuação +1
            else:
                status = "Fora do intervalo ideal"
                pontuacao = -1  # Pontuação -1

            # Adiciona o resultado detalhado no relatório
            relatorio.append({
                'Marca': marca,
                'Mês': str(mes),  # Convertendo para string para facilitar a visualização
                'Quantidade de Retornos': quantidade_retorno,
                'Status': status,
                'Pontuação': pontuacao
            })

    # Calcular a pontuação total
    fitness_total = sum(item['Pontuação'] for item in relatorio)

    return fitness_total, relatorio

def hill_climbing(file_name, objetivo_retorno_min=50, objetivo_retorno_max=100, max_iter=100):
    """
    Aplica o algoritmo de Hill Climbing para melhorar a pontuação de fitness
    baseado nos retornos de garantia.

    :param file_name: Nome do arquivo Excel com os dados de retornos de garantia.
    :param objetivo_retorno_min: Valor mínimo ideal de retornos de garantia por mês.
    :param objetivo_retorno_max: Valor máximo ideal de retornos de garantia por mês.
    :param max_iter: Número máximo de iterações.
    :return: A melhor pontuação de fitness encontrada.
    """
    # Obter a pontuação inicial
    melhor_fitness, relatorio_atual = fitness_function(file_name, objetivo_retorno_min, objetivo_retorno_max)
    print(f"Pontuação inicial de fitness: {melhor_fitness}")

    for iteracao in range(max_iter):
        print(f"Iteração {iteracao + 1}/{max_iter}...")

        # Criar uma vizinhança para modificar
        # Aqui estamos aleatoriamente ajustando o número de retornos para uma marca
        nova_vizinhança = relatorio_atual.copy()
        marca_a_modificar = random.choice(nova_vizinhança)  # Escolher uma marca aleatória
        marca_a_modificar['Quantidade de Retornos'] = random.randint(30, 150)  # Ajuste aleatório

        # Calcular a pontuação de fitness da nova vizinhança
        novos_fitness, _ = fitness_function(file_name, objetivo_retorno_min, objetivo_retorno_max)

        # Comparar com a melhor pontuação
        if novos_fitness > melhor_fitness:
            melhor_fitness = novos_fitness
            relatorio_atual = nova_vizinhança  # Atualiza a vizinhança

        # Se não houver melhoria, podemos parar
        if novos_fitness == melhor_fitness:
            break

    return melhor_fitness

# Exemplo de uso
file_name = 'autopecas_motor_planilha.xlsx'  # Substitua pelo nome do seu arquivo
fitness_resultado = hill_climbing(file_name, objetivo_retorno_min=50, objetivo_retorno_max=100, max_iter=100)
print(f"A melhor pontuação de fitness encontrada é: {fitness_resultado}")
# Out:
# Pontuação inicial de fitness: 5
# Iteração 1/100...
# A melhor pontuação de fitness encontrada é: 5

# %% [markdown]
# ## Simulated annealing

# %%
import pandas as pd
import os
import random
import math

def fitness_function(file_name, objetivo_retorno_min=50, objetivo_retorno_max=100):
    """
    Avalia a qualidade dos retornos de garantia por marca e mês.
    - A função compara os retornos com os valores ideais e retorna uma pontuação de fitness.

    :param file_name: Nome do arquivo Excel com os dados de retornos de garantia.
    :param objetivo_retorno_min: Valor mínimo ideal de retornos de garantia por mês.
    :param objetivo_retorno_max: Valor máximo ideal de retornos de garantia por mês.
    :return: A pontuação de fitness total para os retornos de garantia.
    """
    # Verifica se o arquivo existe no diretório
    file_path = f'/content/{file_name}'

    if not os.path.exists(file_path):
        print(f"Arquivo '{file_name}' não encontrado no diretório '/content/'.")
        return None

    # Carregar o arquivo XLSX
    df = pd.read_excel(file_path)

    # Verificar se as colunas necessárias existem no DataFrame
    if 'Marca' not in df.columns or 'Retornos de Garantia (Mensal)' not in df.columns:
        print("As colunas necessárias não foram encontradas no arquivo.")
        return None

    # Converter a coluna de 'Retornos de Garantia (Mensal)' para número inteiro
    df['Retornos de Garantia (Mensal)'] = pd.to_numeric(df['Retornos de Garantia (Mensal)'], errors='coerce')

    # Criar um DataFrame vazio para armazenar os retornos por marca e mês
    retornos_por_marca_mes = []

    # Iterar sobre cada linha para organizar os retornos por marca e mês
    for index, row in df.iterrows():
        mes = pd.to_datetime('today').replace(day=1)  # Primeiro dia do mês atual
        marca = row['Marca']
        quantidade_retorno = row['Retornos de Garantia (Mensal)']

        # Adiciona para o mês atual
        retornos_por_marca_mes.append([marca, mes, quantidade_retorno])

    # Criar um DataFrame com os retornos por marca e mês
    retornos_df = pd.DataFrame(retornos_por_marca_mes, columns=['Marca', 'Mes', 'Retornos'])

    # Garantir que 'Mes' esteja no formato datetime para agrupamento adequado
    retornos_df['Mes'] = pd.to_datetime(retornos_df['Mes']).dt.to_period('M')

    # Agrupar por 'Marca' e 'Mes' e somar os retornos de garantia (quantidade de peças retornadas)
    resultados = retornos_df.groupby(['Marca', 'Mes'])['Retornos'].sum().unstack(fill_value=0)

    # Se não houver dados
    if resultados.empty:
        print("Não há registros de retorno de garantia.")
        return None

    # Relatório detalhado sobre os resultados
    relatorio = []

    # Avaliar cada valor de retorno de garantia
    for marca in resultados.index:
        for mes in resultados.columns:
            quantidade_retorno = resultados.loc[marca, mes]

            # Criar a avaliação para cada marca/mês
            if objetivo_retorno_min <= quantidade_retorno <= objetivo_retorno_max:
                status = "Dentro do intervalo ideal"
                pontuacao = 1  # Pontuação +1
            else:
                status = "Fora do intervalo ideal"
                pontuacao = -1  # Pontuação -1

            # Adiciona o resultado detalhado no relatório
            relatorio.append({
                'Marca': marca,
                'Mês': str(mes),  # Convertendo para string para facilitar a visualização
                'Quantidade de Retornos': quantidade_retorno,
                'Status': status,
                'Pontuação': pontuacao
            })

    # Calcular a pontuação total
    fitness_total = sum(item['Pontuação'] for item in relatorio)

    return fitness_total, relatorio

def simulated_annealing(file_name, objetivo_retorno_min=50, objetivo_retorno_max=100, temp_inicial=1000, temp_final=1, alpha=0.95, max_iter=1000):
    """
    Aplica o algoritmo Simulated Annealing para melhorar a pontuação de fitness
    baseado nos retornos de garantia.

    :param file_name: Nome do arquivo Excel com os dados de retornos de garantia.
    :param objetivo_retorno_min: Valor mínimo ideal de retornos de garantia por mês.
    :param objetivo_retorno_max: Valor máximo ideal de retornos de garantia por mês.
    :param temp_inicial: Temperatura inicial.
    :param temp_final: Temperatura final.
    :param alpha: Taxa de resfriamento (quanto a temperatura diminui a cada iteração).
    :param max_iter: Número máximo de iterações.
    :return: A melhor pontuação de fitness encontrada.
    """

    # Obter a pontuação inicial
    melhor_fitness, relatorio_atual = fitness_function(file_name, objetivo_retorno_min, objetivo_retorno_max)
    print(f"Pontuação inicial de fitness: {melhor_fitness}")

    # Inicializa a temperatura
    temperatura = temp_inicial
    iteracao = 0

    while temperatura > temp_final and iteracao < max_iter:
        iteracao += 1
        print(f"Iteração {iteracao}/{max_iter}, Temperatura: {temperatura:.4f}")

        # Criar uma vizinhança para modificar (ajuste aleatório de uma marca)
        nova_vizinhança = relatorio_atual.copy()
        marca_a_modificar = random.choice(nova_vizinhança)  # Escolher uma marca aleatória
        marca_a_modificar['Quantidade de Retornos'] = random.randint(30, 150)  # Ajuste aleatório

        # Calcular a pontuação de fitness da nova vizinhança
        novos_fitness, _ = fitness_function(file_name, objetivo_retorno_min, objetivo_retorno_max)

        # Se a nova solução for melhor, aceita-a
        if novos_fitness > melhor_fitness:
            melhor_fitness = novos_fitness
            relatorio_atual = nova_vizinhança
        else:
            # Se for pior, aceita com uma probabilidade que depende da temperatura
            delta_fitness = novos_fitness - melhor_fitness
            probabilidade = math.exp(delta_fitness / temperatura)
            if random.random() < probabilidade:
                melhor_fitness = novos_fitness
                relatorio_atual = nova_vizinhança

        # Resfriar a temperatura
        temperatura *= alpha  # Diminui a temperatura

    return melhor_fitness

# Exemplo de uso:
file_name = 'autopecas_motor_planilha.xlsx'  # Substitua pelo nome do seu arquivo
fitness_resultado = simulated_annealing(file_name, objetivo_retorno_min=50, objetivo_retorno_max=100, temp_inicial=1000, temp_final=1, alpha=0.95, max_iter=1000)
print(f"A melhor pontuação de fitness encontrada é: {fitness_resultado}")
# Out:
# Pontuação inicial de fitness: 5
# Iteração 1/1000, Temperatura: 1000.0000
# Iteração 2/1000, Temperatura: 950.0000
# Iteração 3/1000, Temperatura: 902.5000
# Iteração 4/1000, Temperatura: 857.3750
# Iteração 5/1000, Temperatura: 814.5062
# Iteração 6/1000, Temperatura: 773.7809
# Iteração 7/1000, Temperatura: 735.0919
# Iteração 8/1000, Temperatura: 698.3373
# Iteração 9/1000, Temperatura: 663.4204
# Iteração 10/1000, Temperatura: 630.2494
# Iteração 11/1000, Temperatura: 598.7369
# Iteração 12/1000, Temperatura: 568.8001
# Iteração 13/1000, Temperatura: 540.3601
# Iteração 14/1000, Temperatura: 513.3421
# Iteração 15/1000, Temperatura: 487.6750
# Iteração 16/1000, Temperatura: 463.2912
# Iteração 17/1000, Temperatura: 440.1267
# Iteração 18/1000, Temperatura: 418.1203
# Iteração 19/1000, Temperatura: 397.2143
# Iteração 20/1000, Temperatura: 377.3536
# Iteração 21/1000, Temperatura: 358.4859
# Iteração 22/1000, Temperatura: 340.5616
# Iteração 23/1000, Temperatura: 323.5335
# Iteração 24/1000, Temperatura: 307.3569
# Iteração 25/1000, Temperatura: 291.9890
# Iteração 26/1000, Temperatura: 277.3896
# Iteração 27/1000, Temperatura: 263.5201
# Iteração 28/1000, Temperatura: 250.3441
# Iteração 29/1000, Temperatura: 237.8269
# Iteração 30/1000, Temperatura: 225.9355
# Iteração 31/1000, Temperatura: 214.6388
# Iteração 32/1000, Temperatura: 203.9068
# Iteração 33/1000, Temperatura: 193.7115
# Iteração 34/1000, Temperatura: 184.0259
# Iteração 35/1000, Temperatura: 174.8246
# Iteração 36/1000, Temperatura: 166.0834
# Iteração 37/1000, Temperatura: 157.7792
# Iteração 38/1000, Temperatura: 149.8903
# Iteração 39/1000, Temperatura: 142.3957
# Iteração 40/1000, Temperatura: 135.2760
# Iteração 41/1000, Temperatura: 128.5122
# Iteração 42/1000, Temperatura: 122.0865
# Iteração 43/1000, Temperatura: 115.9822
# Iteração 44/1000, Temperatura: 110.1831
# Iteração 45/1000, Temperatura: 104.6740
# Iteração 46/1000, Temperatura: 99.4403
# Iteração 47/1000, Temperatura: 94.4682
# Iteração 48/1000, Temperatura: 89.7448
# Iteração 49/1000, Temperatura: 85.2576
# Iteração 50/1000, Temperatura: 80.9947
# Iteração 51/1000, Temperatura: 76.9450
# Iteração 52/1000, Temperatura: 73.0977
# Iteração 53/1000, Temperatura: 69.4428
# Iteração 54/1000, Temperatura: 65.9707
# Iteração 55/1000, Temperatura: 62.6722
# Iteração 56/1000, Temperatura: 59.5386
# Iteração 57/1000, Temperatura: 56.5616
# Iteração 58/1000, Temperatura: 53.7335
# Iteração 59/1000, Temperatura: 51.0469
# Iteração 60/1000, Temperatura: 48.4945
# Iteração 61/1000, Temperatura: 46.0698
# Iteração 62/1000, Temperatura: 43.7663
# Iteração 63/1000, Temperatura: 41.5780
# Iteração 64/1000, Temperatura: 39.4991
# Iteração 65/1000, Temperatura: 37.5241
# Iteração 66/1000, Temperatura: 35.6479
# Iteração 67/1000, Temperatura: 33.8655
# Iteração 68/1000, Temperatura: 32.1723
# Iteração 69/1000, Temperatura: 30.5636
# Iteração 70/1000, Temperatura: 29.0355
# Iteração 71/1000, Temperatura: 27.5837
# Iteração 72/1000, Temperatura: 26.2045
# Iteração 73/1000, Temperatura: 24.8943
# Iteração 74/1000, Temperatura: 23.6496
# Iteração 75/1000, Temperatura: 22.4671
# Iteração 76/1000, Temperatura: 21.3437
# Iteração 77/1000, Temperatura: 20.2765
# Iteração 78/1000, Temperatura: 19.2627
# Iteração 79/1000, Temperatura: 18.2996
# Iteração 80/1000, Temperatura: 17.3846
# Iteração 81/1000, Temperatura: 16.5154
# Iteração 82/1000, Temperatura: 15.6896
# Iteração 83/1000, Temperatura: 14.9051
# Iteração 84/1000, Temperatura: 14.1599
# Iteração 85/1000, Temperatura: 13.4519
# Iteração 86/1000, Temperatura: 12.7793
# Iteração 87/1000, Temperatura: 12.1403
# Iteração 88/1000, Temperatura: 11.5333
# Iteração 89/1000, Temperatura: 10.9566
# Iteração 90/1000, Temperatura: 10.4088
# Iteração 91/1000, Temperatura: 9.8884
# Iteração 92/1000, Temperatura: 9.3939
# Iteração 93/1000, Temperatura: 8.9242
# Iteração 94/1000, Temperatura: 8.4780
# Iteração 95/1000, Temperatura: 8.0541
# Iteração 96/1000, Temperatura: 7.6514
# Iteração 97/1000, Temperatura: 7.2689
# Iteração 98/1000, Temperatura: 6.9054
# Iteração 99/1000, Temperatura: 6.5601
# Iteração 100/1000, Temperatura: 6.2321
# Iteração 101/1000, Temperatura: 5.9205
# Iteração 102/1000, Temperatura: 5.6245
# Iteração 103/1000, Temperatura: 5.3433
# Iteração 104/1000, Temperatura: 5.0761
# Iteração 105/1000, Temperatura: 4.8223
# Iteração 106/1000, Temperatura: 4.5812
# Iteração 107/1000, Temperatura: 4.3521
# Iteração 108/1000, Temperatura: 4.1345
# Iteração 109/1000, Temperatura: 3.9278
# Iteração 110/1000, Temperatura: 3.7314
# Iteração 111/1000, Temperatura: 3.5448
# Iteração 112/1000, Temperatura: 3.3676
# Iteração 113/1000, Temperatura: 3.1992
# Iteração 114/1000, Temperatura: 3.0393
# Iteração 115/1000, Temperatura: 2.8873
# Iteração 116/1000, Temperatura: 2.7429
# Iteração 117/1000, Temperatura: 2.6058
# Iteração 118/1000, Temperatura: 2.4755
# Iteração 119/1000, Temperatura: 2.3517
# Iteração 120/1000, Temperatura: 2.2341
# Iteração 121/1000, Temperatura: 2.1224
# Iteração 122/1000, Temperatura: 2.0163
# Iteração 123/1000, Temperatura: 1.9155
# Iteração 124/1000, Temperatura: 1.8197
# Iteração 125/1000, Temperatura: 1.7287
# Iteração 126/1000, Temperatura: 1.6423
# Iteração 127/1000, Temperatura: 1.5602
# Iteração 128/1000, Temperatura: 1.4822
# Iteração 129/1000, Temperatura: 1.4081
# Iteração 130/1000, Temperatura: 1.3377
# Iteração 131/1000, Temperatura: 1.2708
# Iteração 132/1000, Temperatura: 1.2072
# Iteração 133/1000, Temperatura: 1.1469
# Iteração 134/1000, Temperatura: 1.0895
# Iteração 135/1000, Temperatura: 1.0351
# A melhor pontuação de fitness encontrada é: 5
